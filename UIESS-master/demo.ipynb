# %%
import os

# %%
print("trainA:", len(os.listdir("data/trainA")))
print("trainB:", len(os.listdir("data/trainB")))
print("trainB_label:", len(os.listdir("data/trainB_label")))
print("testA:", len(os.listdir("data/testA")))
print("testB:", len(os.listdir("data/testB")))
# Out:
# trainA: 600
# trainB: 600
# trainB_label: 600
# testA: 290
# testB: 515

# %%
a = sorted(os.listdir("data/trainB"))
b = sorted(os.listdir("data/trainB_label"))

print("Pair match:", a == b)
# Out:
# Pair match: True

# %%
import sys
import os

# Add project path
sys.path.append("./")

print("Setup done ✅")
# Out:
# Setup done ✅

# %%
import train

print("Train module imported ✅")
# Out:
# usage: ipykernel_launcher.py [-h] [--data_root DATA_ROOT] [--epoch EPOCH]
#                              [--n_epochs N_EPOCHS] [--exp_name EXP_NAME]
#                              [--batch_size BATCH_SIZE] [--lr LR] [--b1 B1]
#                              [--b2 B2] [--decay_epoch DECAY_EPOCH]
#                              [--n_cpu N_CPU] [--img_height IMG_HEIGHT]
#                              [--img_width IMG_WIDTH] [--channels CHANNELS]
#                              [--sample_interval SAMPLE_INTERVAL]
#                              [--checkpoint_interval CHECKPOINT_INTERVAL]
#                              [--n_downsample N_DOWNSAMPLE]
#                              [--n_residual N_RESIDUAL] [--dim DIM]
#                              [--style_dim STYLE_DIM] [--gpu GPU] [--seed SEED]
# ipykernel_launcher.py: error: unrecognized arguments: --f=c:\Users\Dhaval\AppData\Roaming\jupyter\runtime\kernel-v37706c05a6f1ed00a53409f9f87445bfea9cdcdd0.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# c:\Minor_Project\venv\Lib\site-packages\IPython\core\interactiveshell.py:3755: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
